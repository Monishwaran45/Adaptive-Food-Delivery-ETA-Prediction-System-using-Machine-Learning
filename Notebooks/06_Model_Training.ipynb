# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import LabelEncoder

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
riders = pd.read_csv("../dataset/processed/riders_features.csv")

print(riders.shape)

riders.head()
# Out:
# (45493, 33)
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd  ... Day_of_Week Month  \
# 0                    78.116106  2022-02-12       21:55  ...    Saturday     2
# 1                    76.347589  2022-02-13       14:55  ...      Sunday     2
# 2                    74.006619  2022-03-04       17:30  ...      Friday     3
# 3                    75.829346  2022-02-13       09:20  ...      Sunday     2
# 4                    80.502929  2022-02-14       19:50  ...      Monday     2
#
#   Weekend  Peak_Period Trip_Distance_km Traffic_Score  Weather_Score  \
# 0       1       Dinner        10.280582             4              4
# 1       1        Lunch         6.242319             3              5
# 2       0       Normal        13.787860             2              6
# 3       1    Breakfast         2.930258             1              6
# 4       0       Dinner        19.396618             4              4
#
#   Vehicle_Score Rider_Experience  Workload
# 0             4            151.2       3.0
# 1             4             98.7       1.0
# 2             3            108.1       1.0
# 3             4            146.2       0.0
# 4             3            112.8       1.0
#
# [5 rows x 33 columns]

# %%
TARGET = "Time_taken (min)"

# %%
drop_columns = [

    "Delivery_person_ID",

    "Order_Date",

    "Time_Orderd",

    "Time_Order_picked",

    "Time_taken (min)"

]

# %%
X = riders.drop(columns=drop_columns)

y = riders[TARGET]

print(X.shape)
print(y.shape)
# Out:
# (45493, 28)
# (45493,)

# %%
categorical_features = X.select_dtypes(include=["object"]).columns.tolist()

numerical_features = X.select_dtypes(exclude=["object"]).columns.tolist()

print("Categorical Features")

print(categorical_features)

print()

print("Numerical Features")

print(numerical_features)
# Out:
# Categorical Features
# ['ID', 'Weather_conditions', 'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival', 'City', 'Order_Time', 'Day_of_Week', 'Peak_Period']
#
# Numerical Features
# ['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude', 'Vehicle_condition', 'multiple_deliveries', 'Order_Hour', 'Pickup_Hour', 'Month', 'Weekend', 'Trip_Distance_km', 'Traffic_Score', 'Weather_Score', 'Vehicle_Score', 'Rider_Experience', 'Workload']

# %%
numeric_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="median"))
    ]
)

categorical_transformer = Pipeline(
    steps=[
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("encoder", OneHotEncoder(handle_unknown="ignore"))
    ]
)
print(numeric_transformer)
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))])

# %%
preprocessor = ColumnTransformer(

    transformers=[

        ("num",
         numeric_transformer,
         numerical_features),

        ("cat",
         categorical_transformer,
         categorical_features)

    ]

)

# %%
X_train, X_test, y_train, y_test = train_test_split(

    X,
    y,

    test_size=0.20,

    random_state=42

)

print(X_train.shape)
print(X_test.shape)
# Out:
# (36394, 28)
# (9099, 28)

# %%
print(X_train.head())

print()

print(y_train.head())
# Out:
#            ID  Delivery_person_Age  Delivery_person_Ratings  \
# 22461  0x6b3b                 33.0                      4.8
# 21478  0x4d31                 22.0                      4.6
# 25583  0x889b                 20.0                      4.9
# 28953   0x436                 30.0                      4.7
# 42949  0xddfe                 29.0                      4.7
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 22461            12.323978             76.627961                   12.433978
# 21478            23.416792             85.316842                   23.526792
# 25583            12.311072             76.654878                   12.391072
# 28953            11.006686             76.951736                   11.036686
# 42949            30.366322             78.070453                   30.386322
#
#        Delivery_location_longitude Weather_conditions Road_traffic_density  \
# 22461                    76.737961             Stormy                  Low
# 21478                    85.426842              Windy               Medium
# 25583                    76.734878             Cloudy                  Jam
# 28953                    76.981736                Fog                  Low
# 42949                    78.090453                Fog                 High
#
#        Vehicle_condition  ... Day_of_Week Month  Weekend Peak_Period  \
# 22461                  2  ...   Wednesday     3        0      Normal
# 21478                  0  ...      Sunday     3        1      Normal
# 25583                  0  ...    Saturday     3        1      Dinner
# 28953                  3  ...      Friday     3        0      Dinner
# 42949                  1  ...      Friday     2        0      Normal
#
#       Trip_Distance_km Traffic_Score  Weather_Score  Vehicle_Score  \
# 22461        17.097973             1              5              4
# 21478        16.597659             2              3              4
# 25583        12.435538             4              2              4
# 28953         4.674295             1              4              3
# 42949         2.937138             3              4              3
#
#       Rider_Experience  Workload
# 22461            158.4       1.0
# 21478            101.2       1.0
# 25583             98.0       2.0
# 28953            141.0       1.0
# 42949            136.3       1.0
#
# [5 rows x 28 columns]
#
# 22461    15
# 21478    25
# 25583    42
# 28953    22
# 42949    30
# Name: Time_taken (min), dtype: int64

# %%
drop_columns = [
    "ID",
    "Order_Date",
    "Time_Orderd",
    "Time_Order_picked",
    "Order_Time",   
    "Time_taken (min)"
]

# %%
X = riders.drop(columns=drop_columns)
y = riders["Time_taken (min)"]

# %%
categorical_features = X.select_dtypes(include=["object"]).columns.tolist()
numerical_features = X.select_dtypes(exclude=["object"]).columns.tolist()

print(categorical_features)
# Out:
# ['Delivery_person_ID', 'Weather_conditions', 'Road_traffic_density', 'Type_of_order', 'Type_of_vehicle', 'Festival', 'City', 'Day_of_Week', 'Peak_Period']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
lr_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", LinearRegression())
    ]
)

# %%
lr_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Delivery_person_Age',
#                                                    'Delivery_person_Ratings',
#                                                    'Restaurant_latitude',
#                                                    'Restaurant_longitude',
#                                                    'Delivery_location_latitude',
#                                                    'Delivery_location_longitude',
#                                                    'Vehicle_condition',
#                                                    'multiple_deliveries',
#                                                    'Order_Hour', 'Pickup_...
#                                                    'Vehicle_Score',
#                                                    'Rider_Experience',
#                                                    'Workload']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['ID', 'Weather_conditions',
#                                                    'Road_traffic_density',
#                                                    'Type_of_order',
#                                                    'Type_of_vehicle',
#                                                    'Festival', 'City',
#                                                    'Order_Time', 'Day_of_Week',
#                                                    'Peak_Period'])])),
#                 ('model', LinearRegression())])

# %%
y_pred = lr_model.predict(X_test)

# %%
print(type(y_pred))
print(y_pred[:10])
# Out:
# <class 'numpy.ndarray'>
# [24.9080155  42.89277766 35.44865742 27.7398216  23.83855812 21.25248149
#  35.79847987 33.92216096 21.56197518 29.0340598 ]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred) ** 0.5
r2 = r2_score(y_test, y_pred)

print(f"MAE  : {mae:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"R²   : {r2:.4f}")
# Out:
# MAE  : 4.77
# RMSE : 6.00
# R²   : 0.5927

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", RandomForestRegressor(
            n_estimators=200,
            max_depth=20,
            min_samples_split=5,
            random_state=42,
            n_jobs=-1
        ))
    ]
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Delivery_person_Age',
#                                                    'Delivery_person_Ratings',
#                                                    'Restaurant_latitude',
#                                                    'Restaurant_longitude',
#                                                    'Delivery_location_latitude',
#                                                    'Delivery_location_longitude',
#                                                    'Vehicle_condition',
#                                                    'multiple_deliveries',
#                                                    'Order_Hour', 'Pickup_...
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['ID', 'Weather_conditions',
#                                                    'Road_traffic_density',
#                                                    'Type_of_order',
#                                                    'Type_of_vehicle',
#                                                    'Festival', 'City',
#                                                    'Order_Time', 'Day_of_Week',
#                                                    'Peak_Period'])])),
#                 ('model',
#                  RandomForestRegressor(max_depth=20, min_samples_split=5,
#                                        n_estimators=200, n_jobs=-1,
#                                        random_state=42))])

# %%
rf_pred = rf_model.predict(X_test)

# %%
rf_mae = mean_absolute_error(y_test, rf_pred)
rf_rmse = mean_squared_error(y_test, rf_pred) ** 0.5
rf_r2 = r2_score(y_test, rf_pred)

print(f"MAE  : {rf_mae:.2f}")
print(f"RMSE : {rf_rmse:.2f}")
print(f"R²   : {rf_r2:.4f}")
# Out:
# MAE  : 3.10
# RMSE : 3.94
# R²   : 0.8243

# %%
from xgboost import XGBRegressor

# %%
xgb_model = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        ("model", XGBRegressor(
            n_estimators=300,
            learning_rate=0.05,
            max_depth=8,
            subsample=0.8,
            colsample_bytree=0.8,
            objective="reg:squarederror",
            random_state=42
        ))
    ]
)

# %%
xgb_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['Delivery_person_Age',
#                                                    'Delivery_person_Ratings',
#                                                    'Restaurant_latitude',
#                                                    'Restaurant_longitude',
#                                                    'Delivery_location_latitude',
#                                                    'Delivery_location_longitude',
#                                                    'Vehicle_condition',
#                                                    'multiple_deliveries',
#                                                    'Order_Hour', 'Pickup_...
#                               feature_types=None, gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.05,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=8, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=300, n_jobs=None,
#                               num_parallel_tree=None, random_state=42, ...))])

# %%
xgb_pred = xgb_model.predict(X_test)

# %%
xgb_mae = mean_absolute_error(y_test, xgb_pred)
xgb_rmse = mean_squared_error(y_test, xgb_pred) ** 0.5
xgb_r2 = r2_score(y_test, xgb_pred)

print(f"MAE  : {xgb_mae:.2f}")
print(f"RMSE : {xgb_rmse:.2f}")
print(f"R²   : {xgb_r2:.4f}")
# Out:
# MAE  : 3.05
# RMSE : 3.83
# R²   : 0.8336

# %%
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor

param_grid = {
    "model__n_estimators": [300, 500, 700],
    "model__max_depth": [6, 8, 10],
    "model__learning_rate": [0.03, 0.05, 0.1],
    "model__subsample": [0.8, 0.9, 1.0],
    "model__colsample_bytree": [0.8, 0.9, 1.0]
}

search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_grid,
    n_iter=20,
    cv=3,
    scoring="neg_mean_absolute_error",
    random_state=42,
    n_jobs=-1,
    verbose=2
)

search.fit(X_train, y_train)

print(search.best_params_)
print(search.best_score_)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# {'model__subsample': 1.0, 'model__n_estimators': 700, 'model__max_depth': 8, 'model__learning_rate': 0.1, 'model__colsample_bytree': 0.9}
# -3.1216903871814563

# %%
import joblib
joblib.dump(lr_model, "../models/linear_regression_eta.pkl")
joblib.dump(rf_model, "../models/random_forest_eta.pkl")
joblib.dump(xgb_model, "../models/xgboost_eta.pkl")

print("All models saved successfully!")
# Out:
# All models saved successfully!
